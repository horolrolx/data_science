# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('data/body.csv', index_col=0)
body_df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
body_df['Height']
# Out:
# Number
# 1       176.0
# 2       175.3
# 3       168.6
# 4       168.1
# 5       175.3
#         ...
# 996     171.8
# 997     171.5
# 998     177.9
# 999     174.4
# 1000    173.5
# Name: Height, Length: 1000, dtype: float64

# %%
body_df['Height'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='Height'>

# %%
sns.kdeplot(body_df['Height'])
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(body_df['Height'], bw=0.5)
# Out:
# /var/folders/5x/qyhn_rn57c1ckbjg691620fw0000gp/T/ipykernel_11093/3061660000.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(body_df['Height'], bw=0.5)
# <Axes: xlabel='Height', ylabel='Density'>

# %%
subway_df = pd.read_csv('data/subway.csv')
subway_df
# Out:
#     line station     in    out
# 0    중앙선      지평     37     28
# 1    중앙선      용문   2064   2103
# 2    중앙선      원덕    375    357
# 3    중앙선      양평   4338   4378
# 4    중앙선      오빈    321    321
# ..   ...     ...    ...    ...
# 586  1호선    종로5가  31245  30678
# 587  1호선    종로3가  38099  36928
# 588  1호선      종각  52310  50088
# 589  1호선      시청  29150  29043
# 590  1호선     서울역  58391  54356
#
# [591 rows x 4 columns]

# %%
sns.kdeplot(subway_df['in'], bw=0.5)
# Out:
# /var/folders/5x/qyhn_rn57c1ckbjg691620fw0000gp/T/ipykernel_11093/1584568860.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(subway_df['in'], bw=0.5)
# <Axes: xlabel='in', ylabel='Density'>

# %%
body_df.plot(kind='hist', y='Height')
# Out:
# <Axes: ylabel='Frequency'>

# %%
body_df.plot(kind='hist', y='Height', bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.distplot(body_df['Height'], bins=15)
# Out:
# /var/folders/5x/qyhn_rn57c1ckbjg691620fw0000gp/T/ipykernel_11093/1821322944.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(body_df['Height'], bins=15)
# <Axes: xlabel='Height', ylabel='Density'>

# %%
body_df.plot(kind='box', y='Height')
# Out:
# <Axes: >

# %%
sns.violinplot(y=body_df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
body_df.plot(kind='scatter', x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(x=body_df['Height'], y=body_df['Weight'])
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(body_df['Height'])
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(body_df['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
df = pd.read_csv('data/salaries.csv')
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service     sex  salary
# 0        Prof          B             56           49    Male  186960
# 1        Prof          A             12            6    Male   93000
# 2        Prof          A             23           20    Male  110515
# 3        Prof          A             40           31    Male  131205
# 4        Prof          B             20           18    Male  104800
# ..        ...        ...            ...          ...     ...     ...
# 73       Prof          B             18           10  Female  105450
# 74  AssocProf          B             19            6  Female  104542
# 75       Prof          B             17           17  Female  124312
# 76       Prof          A             28           14  Female  109954
# 77       Prof          A             23           15  Female  109646
#
# [78 rows x 6 columns]

# %%
sns.violinplot(x=df['salary'])
# Out:
# <Axes: xlabel='salary'>
