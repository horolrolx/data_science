# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('data/body.csv', index_col=0)
body_df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
body_df.plot(kind='scatter', x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.lmplot(data=body_df, x='Height', y='Weight')

# 가운데 선은 회귀선
# 회귀선을 그리는 이유는 데이터의 경향성을 보기 위해서

# 경향성이란 ?
# 데이터의 분포를 보고 어떤 방향으로 데이터가 흘러가는지 알 수 있다.
